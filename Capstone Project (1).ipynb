# %% [markdown]
# # Shopping During Covid-19 LockDown in South Africa

# %% [markdown]
# As South Africa is on Day 2 of a 21-Day National Lock-down to stop the spread of the novel Corona Virus, I have thought it appropriate to include a Lock-down theme in my project.
#
# In South Africa (and a few other places around the world, we are only allowed to buy groceries and get health care.  One of my (and many others') concerns are that many people probably already have the virus and not even know it, and are therefore spreading it around when they do shopping.
# If I could choose, I would rather go to a grocery store which is not near a pharmacy, as a lot of people might want to go to both on their limited outings.
# If I could figure out which grocery stores are further away from pharmacies and vise versa, I could assume that those stores might have less foot traffic and less chances of getting infected.
# I can also add health care facilities where one would assume people go when they suspect that they are ill.  If they are ill, but their symptoms are not severe enough to be admitted to hospital, they might stop by a nearby store or pharmacy on their way home to stock up on food and medicine for their quarantine period.
# For people who want to stay away from other people while shopping, they might also avoid stores and pharmacies near hospitals.
#
# The target audience for this project will be anyone who is looking for the best places to buy their essentials during this lock-down period.
# Some, like me, might want to go to isolated stores where there is a chance of less people.  Yet others might want to go to the closest stores they can get, and maybe where grocery stores and pharmacies are close together.
# Either way, this projects will help with that.

# %%
import pandas as pd
import numpy as np

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be UPDATED:
#
#   conda                                        4.8.2-py37_0 --> 4.8.3-py37_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\Anaconda3

# %% [markdown]
# I Install folium and geopy so that I will be able to draw a map, as well as plot different coordinates on it.

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\programdata\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\programdata\anaconda3\lib\site-packages (from geopy) (1.50)

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.14.0)

# %%
import requests
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

# %% [markdown]
# ## Now I define my Foursquare Credentials and Version

# %%
#Establishing FourSquare Credentials
CLIENT_ID = 'AKBWLJHMGEQFFNUQ0AZYFLMKNQI0LUL4BWVVX43TMR0MCO5N' # your Foursquare ID
CLIENT_SECRET = 'KZEMDT2LQ3SPMR0H13IUQUDPMMMN24KEVEJMUXT2FM2DKNEB' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version


print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AKBWLJHMGEQFFNUQ0AZYFLMKNQI0LUL4BWVVX43TMR0MCO5N
# CLIENT_SECRET:KZEMDT2LQ3SPMR0H13IUQUDPMMMN24KEVEJMUXT2FM2DKNEB

# %%
address = '6 Olympus Street, Florida Hills, Gauteng, South Africa'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -26.1670617 27.925278

# %% [markdown]
# # Grocery Stores

# %% [markdown]
# During the LockDown period, we are only allowed to buy essential items.  These items can be bought at grocery stores.  To cover more venues, I used the Category ID's for Grocery Stores, Convenience Stores, Super Markets, Fruit and Vegetable stores and Butchers
#
# Put your Coordinates in at the en of the URL

# %%
urlFood = "https://api.foursquare.com/v2/venues/explore?categoryId=4bf58dd8d48988d118951735,4d954b0ea243a5684a65b473,52f2ab2ebcbc57f1066b8b46,52f2ab2ebcbc57f1066b8b1c,4bf58dd8d48988d11d951735&client_id=AKBWLJHMGEQFFNUQ0AZYFLMKNQI0LUL4BWVVX43TMR0MCO5N&client_secret=KZEMDT2LQ3SPMR0H13IUQUDPMMMN24KEVEJMUXT2FM2DKNEB&v=20180605&radius=10000&limit=100&ll=-26.1618,%2027.9255"
Groceries_json = requests.get(urlFood).json()
Groceries_json
# Out:
# {'meta': {'code': 200, 'requestId': '5e7f63300de0d9001ba801e8'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'query': 'grocery store',
#   'totalResults': 98,
#   'suggestedBounds': {'ne': {'lat': -26.07179990999991,
#     'lng': 28.025585562255472},
#    'sw': {'lat': -26.25180009000009, 'lng': 27.825414437744527}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e197c6914957dc705e17cac',
#        'name': 'Meat World',
#        'location': {'address': '14th Ave',
#         'crossStreet': 'Bagley Terrace',
#         'lat': -26.14445916759537,
#         'lng': 27.954662118046485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.14445916759537,
#           'lng': 27.954662118046485}],
#         'distance': 3495,
#         'cc': 'ZA',
#         'city': 'Northcliff',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['14th Ave (Bagley Terrace)',
#          'Northcliff',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d11d951735',
#          'name': 'Butcher',
#          'pluralName': 'Butchers',
#          'shortName': 'Butcher',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e197c6914957dc705e17cac-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8432559adffd3a44e8cbcf',
#        'name': 'Florida Junction SUPERSPAR',
#        'location': {'address': 'Ontdekkers Road',
#         'lat': -26.14853357,
#         'lng': 27.90169797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.14853357,
#           'lng': 27.90169797}],
#         'distance': 2799,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Ontdekkers Road',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4d4b7105d754a06375d81259',
#          'name': 'Professional & Other Places',
#          'pluralName': 'Professional & Other Places',
#          'shortName': 'Professional',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '551191672'}},
#       'referralId': 'e-0-4e8432559adffd3a44e8cbcf-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0d10c698102d7f7992e106',
#        'name': 'Impala Fruit And Veg',
#        'location': {'address': 'Beyers Naude',
#         'crossStreet': 'Hocky',
#         'lat': -26.144367875477858,
#         'lng': 27.981085600665573,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.144367875477858,
#           'lng': 27.981085600665573}],
#         'distance': 5883,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beyers Naude (Hocky)',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b1c',
#          'name': 'Fruit & Vegetable Store',
#          'pluralName': 'Fruit & Vegetable Stores',
#          'shortName': 'Fruit & Vegetable Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0d10c698102d7f7992e106-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c306f7366e40f47e585c38b',
#        'name': "Steve's Spar",
#        'location': {'lat': -26.136480625826703,
#         'lng': 27.976233210502325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.136480625826703,
#           'lng': 27.976233210502325}],
#         'distance': 5800,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Randburg', '2194', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c306f7366e40f47e585c38b-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce68b61d99f721ec388a473',
#        'name': 'Checkers Hyper - Constantia Kloof',
#        'location': {'lat': -26.147754869318916,
#         'lng': 27.92149327840853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.147754869318916,
#           'lng': 27.92149327840853}],
#         'distance': 1613,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce68b61d99f721ec388a473-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb99f263db7b713f268229a',
#        'name': 'SPAR',
#        'location': {'address': 'Cnr Hendricks Potgieter Road',
#         'lat': -26.11588137,
#         'lng': 27.89725872,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.11588137,
#           'lng': 27.89725872}],
#         'distance': 5838,
#         'postalCode': '1735',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Cnr Hendricks Potgieter Road',
#          'Roodepoort',
#          '1735',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '554442276'}},
#       'referralId': 'e-0-4bb99f263db7b713f268229a-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54869c7d498e904ff18e7f10',
#        'name': 'Woolworths Lifestyle Crossing',
#        'location': {'lat': -26.114454862134465,
#         'lng': 27.893692206159905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.114454862134465,
#           'lng': 27.893692206159905}],
#         'distance': 6154,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54869c7d498e904ff18e7f10-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3deaeb719460fc654a7320',
#        'name': 'Woolworths Food',
#        'location': {'address': 'Town Square',
#         'crossStreet': 'cnr Hendrik Potgieter Rd & Albert Str',
#         'lat': -26.136499895813163,
#         'lng': 27.918262567040916,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.136499895813163,
#           'lng': 27.918262567040916}],
#         'distance': 2907,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Town Square (cnr Hendrik Potgieter Rd & Albert Str)',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3deaeb719460fc654a7320-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd180655b5ca35d34e781f0',
#        'name': 'SPAR',
#        'location': {'address': 'Palm Court Shopping Centre',
#         'crossStreet': 'cnr J.G. Strydom & Olive Rd',
#         'lat': -26.125605316645036,
#         'lng': 27.93188995142647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.125605316645036,
#           'lng': 27.93188995142647}],
#         'distance': 4079,
#         'cc': 'ZA',
#         'city': 'Weltevredenpark',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Palm Court Shopping Centre (cnr J.G. Strydom & Olive Rd)',
#          'Weltevredenpark',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd180655b5ca35d34e781f0-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca110b8542b224bb8570ba0',
#        'name': 'SPAR',
#        'location': {'address': '172 Smit Street',
#         'lat': -26.1324,
#         'lng': 27.94430577,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1324,
#           'lng': 27.94430577}],
#         'distance': 3773,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['172 Smit Street',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '553193540'}},
#       'referralId': 'e-0-4ca110b8542b224bb8570ba0-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e0f32688877936cb40cc3d4',
#        'name': 'Checkers',
#        'location': {'address': 'Rock Cottage',
#         'crossStreet': 'John Vorster Dr',
#         'lat': -26.104621377209828,
#         'lng': 27.926631535171758,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.104621377209828,
#           'lng': 27.926631535171758}],
#         'distance': 6366,
#         'cc': 'ZA',
#         'city': 'Radiokop',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Rock Cottage (John Vorster Dr)',
#          'Radiokop',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e0f32688877936cb40cc3d4-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca9ccb444a8224b2ca92440',
#        'name': 'Woolworths',
#        'location': {'address': 'Boskruin Shopping Centre',
#         'crossStreet': 'Cnr President Fouche Dr & Hawken Ln',
#         'lat': -26.086776283443353,
#         'lng': 27.959107729382836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.086776283443353,
#           'lng': 27.959107729382836}],
#         'distance': 9001,
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Boskruin Shopping Centre (Cnr President Fouche Dr & Hawken Ln)',
#          'EGoli',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca9ccb444a8224b2ca92440-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509a8493e4b09c10ff2fb286',
#        'name': 'Pick n Pay',
#        'location': {'address': 'Cnr Hendrik Potgieter & Johan Rd',
#         'lat': -26.108820292778844,
#         'lng': 27.886112495759775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.108820292778844,
#           'lng': 27.886112495759775}],
#         'distance': 7090,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Cnr Hendrik Potgieter & Johan Rd',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509a8493e4b09c10ff2fb286-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5166d383e4b0bde59aa0e25f',
#        'name': 'Woolworths',
#        'location': {'address': 'Victory Park',
#         'lat': -26.137721610521446,
#         'lng': 28.008385788155604,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.137721610521446,
#           'lng': 28.008385788155604}],
#         'distance': 8705,
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Victory Park', 'EGoli', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5166d383e4b0bde59aa0e25f-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c22f96c7e85c928b5ecbc21',
#        'name': 'Total',
#        'location': {'address': 'Gordon Road',
#         'lat': -26.16789,
#         'lng': 27.938216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.16789,
#           'lng': 27.938216}],
#         'distance': 1440,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Gordon Road',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '554638395'}},
#       'referralId': 'e-0-4c22f96c7e85c928b5ecbc21-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbca24a8ec3d13a44fc1a28',
#        'name': 'Pick n Pay',
#        'location': {'address': 'Randridge Mall',
#         'crossStreet': 'John Vorster Dr',
#         'lat': -26.101021923697736,
#         'lng': 27.940586472885904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.101021923697736,
#           'lng': 27.940586472885904}],
#         'distance': 6931,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Randridge Mall (John Vorster Dr)',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbca24a8ec3d13a44fc1a28-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d246b397dc74200233c9c71',
#        'name': 'SUPERSPAR Gordon Road',
#        'location': {'address': 'Bergbron Drive',
#         'lat': -26.16352889,
#         'lng': 27.95299504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.16352889,
#           'lng': 27.95299504}],
#         'distance': 2753,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Bergbron Drive',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '554200841'}},
#       'referralId': 'e-0-5d246b397dc74200233c9c71-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e06e6cc52b165b7d7ab44a3',
#        'name': 'SPAR',
#        'location': {'address': 'Fredenharry Road',
#         'lat': -26.12282,
#         'lng': 27.899249,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.12282,
#           'lng': 27.899249}],
#         'distance': 5070,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Fredenharry Road',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '553693191'}},
#       'referralId': 'e-0-4e06e6cc52b165b7d7ab44a3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2ad08cd4c0e5c89abd0b6d',
#        'name': 'Checkers',
#        'location': {'address': 'Jim Fouche Rd',
#         'crossStreet': 'Hendrik Potgieter',
#         'lat': -26.134192206634918,
#         'lng': 27.912053469130058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.134192206634918,
#           'lng': 27.912053469130058}],
#         'distance': 3354,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': "Allen's Nek",
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Jim Fouche Rd (Hendrik Potgieter)',
#          "Allen's Nek",
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e2ad08cd4c0e5c89abd0b6d-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6f78082271c30fff674a60',
#        'name': "TJ's Convenience",
#        'location': {'address': 'Louis St',
#         'crossStreet': 'Beatrix Rd',
#         'lat': -26.148426958549692,
#         'lng': 27.892463207244873,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.148426958549692,
#           'lng': 27.892463207244873}],
#         'distance': 3621,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Louis St (Beatrix Rd)',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6f78082271c30fff674a60-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b714530f964a520c83e2de3',
#        'name': 'Woolworths Food - Greenside',
#        'location': {'address': 'Greenway',
#         'lat': -26.147502339882443,
#         'lng': 28.011915144366224,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.147502339882443,
#           'lng': 28.011915144366224}],
#         'distance': 8780,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Greenway', 'Randburg', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b714530f964a520c83e2de3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ccbd8f0c9b846883aabb8c3',
#        'name': "Pick 'n Pay Honey Junction",
#        'location': {'address': 'Hendrick Potgieter',
#         'lat': -26.10365017257014,
#         'lng': 27.924517978232654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10365017257014,
#           'lng': 27.924517978232654}],
#         'distance': 6473,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Hendrick Potgieter',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ccbd8f0c9b846883aabb8c3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c305f19ed37a593dfcc6803',
#        'name': 'Woolworths',
#        'location': {'address': 'Honeydew Village',
#         'crossStreet': 'Cnr John Vorster Rd & Christiaan De Wet Rd',
#         'lat': -26.105814646203346,
#         'lng': 27.925660103446642,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.105814646203346,
#           'lng': 27.925660103446642}],
#         'distance': 6232,
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Honeydew Village (Cnr John Vorster Rd & Christiaan De Wet Rd)',
#          'EGoli',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c305f19ed37a593dfcc6803-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cc03d0bc97f28002c9406d0',
#        'name': 'Pick n Pay Family Kilburn',
#        'location': {'address': '117 Kilburn Street',
#         'lat': -26.15641368,
#         'lng': 27.88543214,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.15641368,
#           'lng': 27.88543214}],
#         'distance': 4048,
#         'postalCode': '1559',
#         'cc': 'ZA',
#         'city': 'Gauteng',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['117 Kilburn Street',
#          'Gauteng',
#          '1559',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '535605980'}},
#       'referralId': 'e-0-5cc03d0bc97f28002c9406d0-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d24684f33b3200023a2c05e',
#        'name': 'SUPERSPAR Palm Court',
#        'location': {'address': 'JC Strydom Roads',
#         'lat': -26.12576461,
#         'lng': 27.93199671,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.12576461,
#           'lng': 27.93199671}],
#         'distance': 4063,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['JC Strydom Roads',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '551200500'}},
#       'referralId': 'e-0-5d24684f33b3200023a2c05e-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f1bb7aee4b0aa509526ee03',
#        'name': 'Shoprite',
#        'location': {'lat': -26.167664197328534,
#         'lng': 27.965815063552093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.167664197328534,
#           'lng': 27.965815063552093}],
#         'distance': 4080,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f1bb7aee4b0aa509526ee03-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59e856a267af3a7212c597e2',
#        'name': 'Engen Maraisburg',
#        'location': {'address': 'Albertina Sisulu Road',
#         'lat': -26.1841918,
#         'lng': 27.942016,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1841918,
#           'lng': 27.942016}],
#         'distance': 2989,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Albertina Sisulu Road',
#          'Randburg',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '558417733'}},
#       'referralId': 'e-0-59e856a267af3a7212c597e2-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d11f8dd9844b60cec17b8d4',
#        'name': "Khan's Butchery",
#        'location': {'address': 'Queens Ave',
#         'crossStreet': 'College St',
#         'lat': -26.1997979168151,
#         'lng': 28.011448015115946,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1997979168151,
#           'lng': 28.011448015115946}],
#         'distance': 9571,
#         'cc': 'ZA',
#         'city': 'Mayfair',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Queens Ave (College St)',
#          'Mayfair',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d11d951735',
#          'name': 'Butcher',
#          'pluralName': 'Butchers',
#          'shortName': 'Butcher',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d11f8dd9844b60cec17b8d4-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e085d30b61c60b0454aa16d',
#        'name': 'SPAR',
#        'location': {'address': 'Beatrice street',
#         'lat': -26.120736212954203,
#         'lng': 27.978460893553684,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.120736212954203,
#           'lng': 27.978460893553684}],
#         'distance': 6993,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beatrice street',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e085d30b61c60b0454aa16d-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a032cbd67af3a450d0b7fd8',
#        'name': 'Engen Siyabonga Convenience Centre',
#        'location': {'address': 'Main Reef Road',
#         'lat': -26.1896747,
#         'lng': 27.916602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1896747,
#           'lng': 27.916602}],
#         'distance': 3227,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Main Reef Road',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a032cbd67af3a450d0b7fd8-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c471d1d76d72d7fba173c4d',
#        'name': 'SPAR',
#        'location': {'address': 'Randpark Dr',
#         'lat': -26.10253272698393,
#         'lng': 27.961344956244805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10253272698393,
#           'lng': 27.961344956244805}],
#         'distance': 7507,
#         'cc': 'ZA',
#         'city': 'Randpark Ridge',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Randpark Dr',
#          'Randpark Ridge',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c471d1d76d72d7fba173c4d-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c83ba762f1c236a88224543',
#        'name': 'Woolworths Engen',
#        'location': {'lat': -26.14370410405293,
#         'lng': 28.00750115672717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.14370410405293,
#           'lng': 28.00750115672717}],
#         'distance': 8437,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'emmerentia',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['emmerentia', '2195', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c83ba762f1c236a88224543-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e217f5e52b1f82ffb9eb2be',
#        'name': 'Pick N Pay',
#        'location': {'address': '31 C R Swart Road',
#         'lat': -26.11914136,
#         'lng': 27.8500228,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.11914136,
#           'lng': 27.8500228}],
#         'distance': 8913,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['31 C R Swart Road',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '534758096'}},
#       'referralId': 'e-0-4e217f5e52b1f82ffb9eb2be-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dba9e0a1e7251d53c7facd3',
#        'name': 'Turkish Kebab House',
#        'location': {'address': '79 Church Street, Mayfair',
#         'lat': -26.20291267573342,
#         'lng': 28.012241760250454,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.20291267573342,
#           'lng': 28.012241760250454}],
#         'distance': 9799,
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['79 Church Street, Mayfair',
#          'EGoli',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#          'name': 'Turkish Restaurant',
#          'pluralName': 'Turkish Restaurants',
#          'shortName': 'Turkish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dba9e0a1e7251d53c7facd3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca4a8d15720b1f7c7f23bef',
#        'name': 'Woolworths',
#        'location': {'address': 'Verdi Shopping Centre',
#         'crossStreet': 'Cnr Beyers Naude Dr & Vincent Rd',
#         'lat': -26.139778232461442,
#         'lng': 27.97892980698712,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.139778232461442,
#           'lng': 27.97892980698712}],
#         'distance': 5874,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Verdi Shopping Centre (Cnr Beyers Naude Dr & Vincent Rd)',
#          'EGoli',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca4a8d15720b1f7c7f23bef-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdb0aa30ef39c7477ca1d2d',
#        'name': 'Pick n Pay',
#        'location': {'address': 'Beyers Naude',
#         'crossStreet': 'Milner',
#         'lat': -26.144182306620767,
#         'lng': 27.984386571069262,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.144182306620767,
#           'lng': 27.984386571069262}],
#         'distance': 6202,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beyers Naude (Milner)',
#          'Randburg',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdb0aa30ef39c7477ca1d2d-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb1cbb5562d224bc78a2188',
#        'name': 'Sasol',
#        'location': {'address': 'Cnr Christiaan De Wet Rd & Wilhelmina Ave',
#         'lat': -26.1321649,
#         'lng': 27.900534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1321649,
#           'lng': 27.900534}],
#         'distance': 4136,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Cnr Christiaan De Wet Rd & Wilhelmina Ave',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '560366948'}},
#       'referralId': 'e-0-4cb1cbb5562d224bc78a2188-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0f591a336220a1e2a2cd77',
#        'name': 'Pick n Pay',
#        'location': {'address': 'Shop LM50, Clearwater Mall',
#         'crossStreet': 'Cnr. Hendrik Potgieter Rd. & Christiaan De Wet Rd.',
#         'lat': -26.127794906030886,
#         'lng': 27.903360259692935,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.127794906030886,
#           'lng': 27.903360259692935}],
#         'distance': 4384,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Shop LM50, Clearwater Mall (Cnr. Hendrik Potgieter Rd. & Christiaan De Wet Rd.)',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0f591a336220a1e2a2cd77-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e36e26dd4c06343483cb33d',
#        'name': 'SPAR',
#        'location': {'address': 'Paul Kruger Road',
#         'lat': -26.10035564,
#         'lng': 27.9063077,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10035564,
#           'lng': 27.9063077}],
#         'distance': 7103,
#         'postalCode': '2170',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Paul Kruger Road',
#          'Roodepoort',
#          '2170',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '553693181'}},
#       'referralId': 'e-0-4e36e26dd4c06343483cb33d-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7bbff597028cfa23b8e1fe',
#        'name': 'SPAR',
#        'location': {'address': 'Fountains Centre, Rabie St',
#         'crossStreet': 'Republic Rd',
#         'lat': -26.10437434624244,
#         'lng': 27.9771511679987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10437434624244,
#           'lng': 27.9771511679987}],
#         'distance': 8216,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Fountains Centre, Rabie St (Republic Rd)',
# ...
#       'referralId': 'e-0-4d400b941bd2a14354b5ee7c-84'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d80dbf5dbc5f04d4085ffb6',
#        'name': 'Pick n Pay Witpoortjie',
#        'location': {'lat': -26.14173610268489,
#         'lng': 27.832084393268957,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.14173610268489,
#           'lng': 27.832084393268957}],
#         'distance': 9597,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Roodepoort', 'iNingizimu Afrika']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d80dbf5dbc5f04d4085ffb6-85'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cc03c74135b39002ceeb944',
#        'name': 'Pick n Pay Family Witpoortjie',
#        'location': {'address': 'Gerrit Maritz Street',
#         'lat': -26.14116,
#         'lng': 27.83164,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.14116,
#           'lng': 27.83164}],
#         'distance': 9656,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Gerrit Maritz Street',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '539857555'}},
#       'referralId': 'e-0-5cc03c74135b39002ceeb944-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59ef2ff7135b3955102c1184',
#        'name': 'Engen Cj Service Station',
#        'location': {'address': '396 Rustenburg Rd',
#         'lat': -26.13468407,
#         'lng': 28.00587346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13468407,
#           'lng': 28.00587346}],
#         'distance': 8579,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['396 Rustenburg Rd',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '560368418'}},
#       'referralId': 'e-0-59ef2ff7135b3955102c1184-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de88966fa76fd1168a3131b',
#        'name': 'OK Foods',
#        'location': {'address': 'Canterbury Crossing',
#         'crossStreet': 'cnr Bram Fisher Dr & Hunter St',
#         'lat': -26.106700324345724,
#         'lng': 28.001147931646194,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.106700324345724,
#           'lng': 28.001147931646194}],
#         'distance': 9735,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'neighborhood': 'Blairgowrie',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Canterbury Crossing (cnr Bram Fisher Dr & Hunter St)',
#          'Randburg',
#          '2194',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de88966fa76fd1168a3131b-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d46e4e81911a093acffefd8',
#        'name': 'Pick n Pay',
#        'location': {'address': 'Campus Square',
#         'crossStreet': 'Cnr Kingsway and University Rd',
#         'lat': -26.18227373744992,
#         'lng': 28.003428104116416,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.18227373744992,
#           'lng': 28.003428104116416}],
#         'distance': 8112,
#         'cc': 'ZA',
#         'city': 'Auckland Park',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Campus Square (Cnr Kingsway and University Rd)',
#          'Auckland Park',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d46e4e81911a093acffefd8-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a0ad99ec97f2843cf89363d',
#        'name': 'Sasol Roodekruin',
#        'location': {'address': 'Cnr C R Swart & Ouklip Rd',
#         'lat': -26.1092714,
#         'lng': 27.8557212,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1092714,
#           'lng': 27.8557212}],
#         'distance': 9100,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Cnr C R Swart & Ouklip Rd',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '576237435'}},
#       'referralId': 'e-0-5a0ad99ec97f2843cf89363d-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a032a888c812a5c1ce6112c',
#        'name': 'Engen Garden City Quickfill',
#        'location': {'address': 'Bartlettweg',
#         'lat': -26.19773037,
#         'lng': 28.00742207,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.19773037,
#           'lng': 28.00742207}],
#         'distance': 9109,
#         'postalCode': '2092',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Bartlettweg',
#          'EGoli',
#          '2092',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '575460895'}},
#       'referralId': 'e-0-5a032a888c812a5c1ce6112c-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a032a604382ab374065d278',
#        'name': 'Engen Zaks Convenience Centre',
#        'location': {'address': '1862 Marthinus Smuts Drive',
#         'lat': -26.24356855,
#         'lng': 27.94052247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.24356855,
#           'lng': 27.94052247}],
#         'distance': 9225,
#         'postalCode': '1804',
#         'cc': 'ZA',
#         'city': 'Diepkloof',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['1862 Marthinus Smuts Drive',
#          'Diepkloof',
#          '1804',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '563117426'}},
#       'referralId': 'e-0-5a032a604382ab374065d278-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd88f08e4b02579a196a00f',
#        'name': 'Engen Mintys Tyres & Mags Amalgam',
#        'location': {'address': 'Production Road',
#         'lat': -26.21284573,
#         'lng': 27.99933137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.21284573,
#           'lng': 27.99933137}],
#         'distance': 9310,
#         'postalCode': '2092',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Production Road',
#          'EGoli',
#          '2092',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd88f08e4b02579a196a00f-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a032a52b8fd9d26beac14a3',
#        'name': 'Engen Tahero Convenience Centre',
#        'location': {'address': '628 Corlett Ave',
#         'lat': -26.15656736,
#         'lng': 27.83242115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.15656736,
#           'lng': 27.83242115}],
#         'distance': 9318,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['628 Corlett Ave',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '564619421'}},
#       'referralId': 'e-0-5a032a52b8fd9d26beac14a3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc1212afa764d03e9f6ad83',
#        'name': 'SPAR Witpoortjie',
#        'location': {'address': '34 General Pienaar Avenue',
#         'lat': -26.13342062,
#         'lng': 27.83443098,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13342062,
#           'lng': 27.83443098}],
#         'distance': 9632,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['34 General Pienaar Avenue',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '557498602'}},
#       'referralId': 'e-0-4dc1212afa764d03e9f6ad83-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d943c7ce923721e4c8667fe',
#        'name': 'SPAR Blairgowrie',
#        'location': {'address': '70 Conrad Drive',
#         'lat': -26.1157688,
#         'lng': 28.01094064,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1157688,
#           'lng': 28.01094064}],
#         'distance': 9958,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'city': 'Blairgowrie',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['70 Conrad Drive',
#          'Blairgowrie',
#          '2194',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '554442232'}},
#       'referralId': 'e-0-4d943c7ce923721e4c8667fe-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59ef2fc978782c46de499662',
#        'name': 'Engen Strijdom Park Convenience Centre',
#        'location': {'address': '1494 Malibongwe Dr',
#         'lat': -26.08657088,
#         'lng': 27.98011063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.08657088,
#           'lng': 27.98011063}],
#         'distance': 9996,
#         'postalCode': '2169',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['1494 Malibongwe Dr',
#          'Randburg',
#          '2169',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '560118333'}},
#       'referralId': 'e-0-59ef2fc978782c46de499662-97'}]}]}}

# %% [markdown]
# The next step is to clean the Json file and create a dataframe with columns and rows.

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
venues = Groceries_json['response']['groups'][0]['items']
    
Grocery_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
Grocery_venues =Grocery_venues.loc[:, filtered_columns]

# filter the category for each row
Grocery_venues['venue.categories'] = Grocery_venues.apply(get_category_type, axis=1)

# clean columns
Grocery_venues.columns = [col.split(".")[-1] for col in Grocery_venues.columns]

Grocery_venues
# Out:
#                                       name                   categories  \
# 0                               Meat World                      Butcher
# 1               Florida Junction SUPERSPAR  Professional & Other Places
# 2                     Impala Fruit And Veg      Fruit & Vegetable Store
# 3                             Steve's Spar                Grocery Store
# 4        Checkers Hyper - Constantia Kloof                Grocery Store
# ..                                     ...                          ...
# 93       Engen Mintys Tyres & Mags Amalgam                  Gas Station
# 94         Engen Tahero Convenience Centre                  Gas Station
# 95                        SPAR Witpoortjie                Deli / Bodega
# 96                        SPAR Blairgowrie                Deli / Bodega
# 97  Engen Strijdom Park Convenience Centre                  Gas Station
#
#           lat        lng
# 0  -26.144459  27.954662
# 1  -26.148534  27.901698
# 2  -26.144368  27.981086
# 3  -26.136481  27.976233
# 4  -26.147755  27.921493
# ..        ...        ...
# 93 -26.212846  27.999331
# 94 -26.156567  27.832421
# 95 -26.133421  27.834431
# 96 -26.115769  28.010941
# 97 -26.086571  27.980111
#
# [98 rows x 4 columns]

# %% [markdown]
# ## Map of all the Grocery Stores in the area (Blue Dots)
#
# I use Geocode and Folium to draw up a map and pinpoint locations. All the locations for Grocery stores are pinned in Blue.

# %%
GroceryShop = folium.Map(location=[-26.1618,27.9255],zoom_start=13)
for lat, lng, name, categories in zip(Grocery_venues['lat'], Grocery_venues['lng'], Grocery_venues['name'], Grocery_venues['categories']):
    label = '{}, {}'.format(categories, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(GroceryShop) 
    
GroceryShop
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Pharmacies

# %% [markdown]
# For this Foursquare search, I used the Category ID's for Pharmacies, Drug Stores and medical Supply Stores

# %%
urlMeds = "https://api.foursquare.com/v2/venues/explore?categoryId=5745c2e4498e11e7bccabdbd,4bf58dd8d48988d10f951735,58daa1558bbb0b01f18ec206&client_id=AKBWLJHMGEQFFNUQ0AZYFLMKNQI0LUL4BWVVX43TMR0MCO5N&client_secret=KZEMDT2LQ3SPMR0H13IUQUDPMMMN24KEVEJMUXT2FM2DKNEB&v=20180605&radius=10000&limit=100&ll=-26.1618,%2027.9255"
BuyMedicine_json = requests.get(urlMeds).json()
BuyMedicine_json
# Out:
# {'meta': {'code': 200, 'requestId': '5e7f47daad1ab4001bac91c2'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'query': 'drugstore',
#   'totalResults': 45,
#   'suggestedBounds': {'ne': {'lat': -26.07179990999991,
#     'lng': 28.025585562255472},
#    'sw': {'lat': -26.25180009000009, 'lng': 27.825414437744527}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d1067689302a35dc9e27a6e',
#        'name': 'Dis-Chem',
#        'location': {'address': '1724 Christiaan de Wet Road',
#         'crossStreet': 'Christiaan De Wet Rd. & Hendrik Potgieter Rd.',
#         'lat': -26.126857967380193,
#         'lng': 27.90485466137693,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.126857967380193,
#           'lng': 27.90485466137693}],
#         'distance': 4402,
#         'postalCode': '1735',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['1724 Christiaan de Wet Road (Christiaan De Wet Rd. & Hendrik Potgieter Rd.)',
#          'Roodepoort',
#          '1735',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d1067689302a35dc9e27a6e-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf3aed41457a090df1648c6',
#        'name': 'Dis-Chem',
#        'location': {'address': 'Shop 7 Retail Crossing Shopping Centre',
#         'crossStreet': 'Cnr. Hendrik Potgieter & Nic Diedrichs Blvd. Wilge',
#         'lat': -26.11542467434798,
#         'lng': 27.8969483057024,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.11542467434798,
#           'lng': 27.8969483057024}],
#         'distance': 5898,
#         'postalCode': '1735',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Shop 7 Retail Crossing Shopping Centre (Cnr. Hendrik Potgieter & Nic Diedrichs Blvd. Wilge)',
#          'Roodepoort',
#          '1735',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf3aed41457a090df1648c6-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e4bfcb5e6eda0000719b176',
#        'name': 'The Local Choice Pharmacy Park',
#        'location': {'address': 'Honeyball Avenue',
#         'lat': -26.15944,
#         'lng': 27.904598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.15944,
#           'lng': 27.904598}],
#         'distance': 2104,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Honeyball Avenue',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '577559795'}},
#       'referralId': 'e-0-5e4bfcb5e6eda0000719b176-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ce3e5df8496ca0039184340',
#        'name': 'Medicare Pharmacy',
#        'location': {'address': '14th Avenue',
#         'lat': -26.150692,
#         'lng': 27.943865,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.150692,
#           'lng': 27.943865}],
#         'distance': 2212,
#         'postalCode': '2170',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['14th Avenue',
#          'Randburg',
#          '2170',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '560914299'}},
#       'referralId': 'e-0-5ce3e5df8496ca0039184340-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6644a51495676d5759340f',
#        'name': 'The Local Choice Pharmacy El Corro',
#        'location': {'address': '130 Weltevreden Rd',
#         'lat': -26.1445799,
#         'lng': 27.9544636,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1445799,
#           'lng': 27.9544636}],
#         'distance': 3471,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['130 Weltevreden Rd',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '567549280'}},
#       'referralId': 'e-0-4e6644a51495676d5759340f-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d2d620ba40da35dfc849177',
#        'name': 'Clicks',
#        'location': {'address': 'Town Square',
#         'crossStreet': 'Hendrik Potgieter',
#         'lat': -26.136924442777964,
#         'lng': 27.918600513017196,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.136924442777964,
#           'lng': 27.918600513017196}],
#         'distance': 2853,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Town Square (Hendrik Potgieter)',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d2d620ba40da35dfc849177-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d68e01467d8a200075fbaea',
#        'name': 'Medicare Pharmacy Palm Court',
#        'location': {'address': 'J.G. Strydom Rd',
#         'lat': -26.1257831,
#         'lng': 27.93212243,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1257831,
#           'lng': 27.93212243}],
#         'distance': 4063,
#         'postalCode': '1709',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['J.G. Strydom Rd',
#          'Roodepoort',
#          '1709',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '558416059'}},
#       'referralId': 'e-0-5d68e01467d8a200075fbaea-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4deb391c52b11677f050dbe2',
#        'name': 'Dis-Chem',
#        'location': {'address': 'Victory Park Shopping Centre',
#         'crossStreet': 'Rustenburg Road',
#         'lat': -26.137963730298964,
#         'lng': 28.008667128990083,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.137963730298964,
#           'lng': 28.008667128990083}],
#         'distance': 8723,
#         'cc': 'ZA',
#         'city': 'Victory Park',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Victory Park Shopping Centre (Rustenburg Road)',
#          'Victory Park',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4deb391c52b11677f050dbe2-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc4234fd43ba14389eb64f8',
#        'name': 'Clicks',
#        'location': {'address': 'Clearwater Mall, Shop LM65, Hendrik Potgieter Rd.',
#         'crossStreet': 'Christiaan De Wet Rd.',
#         'lat': -26.127674062651025,
#         'lng': 27.9037982521583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.127674062651025,
#           'lng': 27.9037982521583}],
#         'distance': 4374,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Clearwater Mall, Shop LM65, Hendrik Potgieter Rd. (Christiaan De Wet Rd.)',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc4234fd43ba14389eb64f8-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d887ac07d4c5481e5b83f71',
#        'name': 'Dis-Chem',
#        'location': {'address': 'Verdi Centre, Beyers Naude Dr.',
#         'crossStreet': 'at Vincent Rd.',
#         'lat': -26.139734196780825,
#         'lng': 27.978988535257077,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.139734196780825,
#           'lng': 27.978988535257077}],
#         'distance': 5882,
#         'cc': 'ZA',
#         'city': 'Risidale',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Verdi Centre, Beyers Naude Dr. (at Vincent Rd.)',
#          'Risidale',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d887ac07d4c5481e5b83f71-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3dec6c719460fcc14b7320',
#        'name': 'Clicks Heathway Square',
#        'location': {'address': 'Beyers Naude Drive',
#         'crossStreet': 'Pendoring Road',
#         'lat': -26.127699641782083,
#         'lng': 27.967629432678223,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.127699641782083,
#           'lng': 27.967629432678223}],
#         'distance': 5668,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beyers Naude Drive (Pendoring Road)',
#          'Randburg',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3dec6c719460fcc14b7320-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d68e0116637d10007a5372b',
#        'name': 'Medicare Pharmacy Weltevreden',
#        'location': {'address': 'Acacia Rd',
#         'lat': -26.134243,
#         'lng': 27.97418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.134243,
#           'lng': 27.97418}],
#         'distance': 5750,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Acacia Rd',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '562171870'}},
#       'referralId': 'e-0-5d68e0116637d10007a5372b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0902ad6071a593bf19dd32',
#        'name': 'Weltevreden Pharmacy',
#        'location': {'lat': -26.134179464752638,
#         'lng': 27.97421607920278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.134179464752638,
#           'lng': 27.97421607920278}],
#         'distance': 5757,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0902ad6071a593bf19dd32-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b1e750f851de500396316d8',
#        'name': 'Dis-Chem Pharmacy Retail Crossing - Strubensvalley',
#        'location': {'address': 'Nic Diederichs Road',
#         'lat': -26.1164723,
#         'lng': 27.89712525,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1164723,
#           'lng': 27.89712525}],
#         'distance': 5788,
#         'postalCode': '1735',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Nic Diederichs Road',
#          'EGoli',
#          '1735',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b1e750f851de500396316d8-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b1e75210d0877001c2af7ca',
#        'name': 'Dis-Chem Pharmacy Verdi',
#        'location': {'address': '4 Vincent Road',
#         'lat': -26.1396,
#         'lng': 27.97902825,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1396,
#           'lng': 27.97902825}],
#         'distance': 5892,
#         'postalCode': '2091',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['4 Vincent Road',
#          'EGoli',
#          '2091',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b1e75210d0877001c2af7ca-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b1e749cbb8d36002c620f85',
#        'name': 'Dis-Chem Pharmacy Cresta',
#        'location': {'address': 'Weltevreden Road',
#         'lat': -26.13109622,
#         'lng': 27.97651183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13109622,
#           'lng': 27.97651183}],
#         'distance': 6137,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Weltevreden Road',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b1e749cbb8d36002c620f85-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c722837d944224b6e090c29',
#        'name': 'Dis-Chem',
#        'location': {'address': 'Randridge Mall',
#         'crossStreet': 'John Vorster Dr',
#         'lat': -26.10131085456717,
#         'lng': 27.941109045535555,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10131085456717,
#           'lng': 27.941109045535555}],
#         'distance': 6911,
#         'cc': 'ZA',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Randridge Mall (John Vorster Dr)',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c722837d944224b6e090c29-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b1e7550e1f2280039b7bda6',
#        'name': 'Dis-Chem Pharmacy Westgate',
#        'location': {'address': '120 Ontdekkers Road',
#         'lat': -26.14001726,
#         'lng': 27.86215499,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.14001726,
#           'lng': 27.86215499}],
#         'distance': 6778,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['120 Ontdekkers Road',
#          'EGoli',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b1e7550e1f2280039b7bda6-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b22aac048b04e002cf6253a',
#        'name': 'Dis-Chem Pharmacy Randridge',
#        'location': {'address': '89 Ferero Avenue',
#         'lat': -26.10195,
#         'lng': 27.94,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10195,
#           'lng': 27.94}],
#         'distance': 6818,
#         'postalCode': '2169',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['89 Ferero Avenue',
#          'Randburg',
#          '2169',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b22aac048b04e002cf6253a-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bee67eae24d20a123e57214',
#        'name': 'Clicks',
#        'location': {'address': 'Beyers Naude Dr',
#         'crossStreet': 'Weltevreden Rd',
#         'lat': -26.13061707155596,
#         'lng': 27.97415811121137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13061707155596,
#           'lng': 27.97415811121137}],
#         'distance': 5974,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'neighborhood': 'Cresta',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beyers Naude Dr (Weltevreden Rd)',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bee67eae24d20a123e57214-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5133074de4b01d3a719a492b',
#        'name': 'Dis-chem',
#        'location': {'lat': -26.13590785902878,
#         'lng': 27.860186783501405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13590785902878,
#           'lng': 27.860186783501405}],
#         'distance': 7134,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5133074de4b01d3a719a492b-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5650d248ea6ea8004adfa3',
#        'name': 'Dis-Chem',
#        'location': {'address': 'Beyers Naude Dr',
#         'crossStreet': 'Weltevreden Rd',
#         'lat': -26.13099407222623,
#         'lng': 27.976093085753718,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13099407222623,
#           'lng': 27.976093085753718}],
#         'distance': 6108,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'neighborhood': 'Cresta',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beyers Naude Dr (Weltevreden Rd)',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5650d248ea6ea8004adfa3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cdd3b9346e1b6002c007c5b',
#        'name': 'Medicare Pharmacy Linden',
#        'location': {'address': '63 3rd Ave',
#         'lat': -26.135817,
#         'lng': 27.993101,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.135817,
#           'lng': 27.993101}],
#         'distance': 7348,
#         'postalCode': '2104',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['63 3rd Ave',
#          'Randburg',
#          '2104',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '564911206'}},
#       'referralId': 'e-0-5cdd3b9346e1b6002c007c5b-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de10db752b1c1b3ce418f92',
#        'name': 'Clicks Honey Crest',
#        'location': {'address': 'Beyers Naude',
#         'lat': -26.093812640787768,
#         'lng': 27.940457797485436,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.093812640787768,
#           'lng': 27.940457797485436}],
#         'distance': 7714,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beyers Naude', 'Randburg', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de10db752b1c1b3ce418f92-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4c5f0d42b4d13ab9a5ff7f',
#        'name': 'Mays Chemist',
#        'location': {'address': '11 Main Rd.',
#         'crossStreet': '4th Ave.',
#         'lat': -26.176726458169956,
#         'lng': 28.000973324321293,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.176726458169956,
#           'lng': 28.000973324321293}],
#         'distance': 7721,
#         'postalCode': '2092',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['11 Main Rd. (4th Ave.)',
#          'EGoli',
#          '2092',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4c5f0d42b4d13ab9a5ff7f-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b1e745f35d3fc002c8b3603',
#        'name': 'Dis-Chem Pharmacy Melville',
#        'location': {'address': '25 Kingsway Avenue',
#         'lat': -26.18261,
#         'lng': 28.00301,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.18261,
#           'lng': 28.00301}],
#         'distance': 8082,
#         'postalCode': '2092',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['25 Kingsway Avenue',
#          'EGoli',
#          '2092',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b1e745f35d3fc002c8b3603-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca442437f84224b20ddcb58',
#        'name': 'Guardian Pharmacy',
#        'location': {'address': 'Fontainebleau',
#         'lat': -26.104371,
#         'lng': 27.977083,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.104371,
#           'lng': 27.977083}],
#         'distance': 8212,
#         'postalCode': '2032',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Fontainebleau',
#          'Randburg',
#          '2032',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca442437f84224b20ddcb58-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7bd441f964a520b26f2fe3',
#        'name': 'Clicks',
#        'location': {'lat': -26.18175592526316,
#         'lng': 28.004670539937674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.18175592526316,
#           'lng': 28.004670539937674}],
#         'distance': 8215,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7bd441f964a520b26f2fe3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cdd3a941ffed7002cf69559',
#        'name': 'Medicare Pharmacy Fontainebleau',
#        'location': {'address': 'Rabie St',
#         'lat': -26.10411837,
#         'lng': 27.97719,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10411837,
#           'lng': 27.97719}],
#         'distance': 8241,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Rabie St',
#          'Randburg',
#          '2194',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '564161397'}},
#       'referralId': 'e-0-5cdd3a941ffed7002cf69559-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b1e7596bb8d36002c630bf9',
#        'name': 'Dis-Chem Pharmacy Princess Crossing - Roodepoort',
#        'location': {'address': '54 Ontdekkers Drive',
#         'lat': -26.13050835,
#         'lng': 27.84957749,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13050835,
#           'lng': 27.84957749}],
#         'distance': 8348,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['54 Ontdekkers Drive',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b1e7596bb8d36002c630bf9-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4403d4befe236a6e22f0e2',
#        'name': 'Dis-chem',
#        'location': {'address': 'Ontdekkers Rd.',
#         'lat': -26.125911827288665,
#         'lng': 27.851561928264157,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.125911827288665,
#           'lng': 27.851561928264157}],
#         'distance': 8399,
#         'postalCode': '1739',
#         'cc': 'ZA',
#         'city': 'Princess Crossing',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Ontdekkers Rd.',
#          'Princess Crossing',
#          '1739',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4403d4befe236a6e22f0e2-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ce81195f0b490002cdaac78',
#        'name': 'Medicare Pharmacy Greenhill',
#        'location': {'address': '36C Greenhill Rd',
#         'lat': -26.16196383,
#         'lng': 28.01187307,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.16196383,
#           'lng': 28.01187307}],
#         'distance': 8629,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['36C Greenhill Rd',
#          'EGoli',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '559413291'}},
#       'referralId': 'e-0-5ce81195f0b490002cdaac78-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2006ff7dc9e1002c952c64',
#        'name': 'Dis-Chem Pharmacy Victory Park',
#        'location': {'address': '1 Rustenburg Road',
#         'lat': -26.13826507,
#         'lng': 28.0085614,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.13826507,
#           'lng': 28.0085614}],
#         'distance': 8703,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['1 Rustenburg Road',
#          'Randburg',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2006ff7dc9e1002c952c64-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e0432bfd4c0684466197984',
#        'name': 'Greenside Pharmacy',
#        'location': {'lat': -26.147415720402172,
#         'lng': 28.01235795021057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.147415720402172,
#           'lng': 28.01235795021057}],
#         'distance': 8825,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Randburg', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e0432bfd4c0684466197984-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d43ff101911a0937856d3d8',
#        'name': 'Medicare Boskruin Pharmacy',
#        'location': {'lat': -26.086802,
#         'lng': 27.95897662639618,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.086802,
#           'lng': 27.95897662639618}],
#         'distance': 8994,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d43ff101911a0937856d3d8-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d678652d3702c0008414fad',
#        'name': 'Medicare Pharmacy Boskruin',
#        'location': {'address': 'President Fouche Drive',
#         'lat': -26.08690268,
#         'lng': 27.95958178,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.08690268,
#           'lng': 27.95958178}],
#         'distance': 9006,
#         'postalCode': '2188',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['President Fouche Drive',
#          'Randburg',
#          '2188',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '561666101'}},
#       'referralId': 'e-0-5d678652d3702c0008414fad-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d652b00486e480008a048ce',
#        'name': 'Dis-Chem Pharmacy Ferndale On Republic',
#        'location': {'address': '186 President Ridge',
#         'lat': -26.099687059577604,
#         'lng': 27.990143647052037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.099687059577604,
#           'lng': 27.990143647052037}],
#         'distance': 9462,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['186 President Ridge',
#          'Randburg',
#          '2194',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '564413299'}},
#       'referralId': 'e-0-5d652b00486e480008a048ce-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ce3eb2a9e0d54002cd7bce4',
#        'name': 'Medicare Pharmacy Parklands',
#        'location': {'address': '31 4th Avenue',
#         'lat': -26.138629,
#         'lng': 28.017531,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.138629,
#           'lng': 28.017531}],
#         'distance': 9551,
#         'postalCode': '2193',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['31 4th Avenue',
#          'Randburg',
#          '2193',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '561413194'}},
#       'referralId': 'e-0-5ce3eb2a9e0d54002cd7bce4-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7b5358775ba737a388ecb4',
#        'name': 'Clicks Pharmacy',
#        'location': {'address': 'Appletons Village',
#         'crossStreet': 'Malibongwe Drive',
#         'lat': -26.094260761438605,
#         'lng': 27.984940748022584,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.094260761438605,
#           'lng': 27.984940748022584}],
#         'distance': 9582,
#         'cc': 'ZA',
#         'city': 'Randburg, Johannesburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Appletons Village (Malibongwe Drive)',
#          'Randburg, Johannesburg',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7b5358775ba737a388ecb4-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e92f8ec0cd629b696f6fe21',
#        'name': 'Witpoortjie Pharmacy',
#        'location': {'address': '36 General Pienaar Avenue',
#         'lat': -26.133185226050532,
#         'lng': 27.834543585777283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.133185226050532,
#           'lng': 27.834543585777283}],
#         'distance': 9630,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Witpoortjie',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['36 General Pienaar Avenue',
#          'Witpoortjie',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e92f8ec0cd629b696f6fe21-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5deae8d8c0b3b1000885a9cc',
#        'name': 'The Local Choice Pharmacy Rox',
#        'location': {'address': '69 Church St',
#         'lat': -26.2035569,
#         'lng': 28.0119761,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.2035569,
#           'lng': 28.0119761}],
#         'distance': 9809,
#         'postalCode': '2092',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['69 Church St',
#          'EGoli',
#          '2092',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '579594567'}},
#       'referralId': 'e-0-5deae8d8c0b3b1000885a9cc-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3999306de7721e2527e649',
#        'name': 'Rox Pharmacy',
#        'location': {'address': '69 Church Street',
#         'crossStreet': 'Railway Street',
#         'lat': -26.203589637153257,
#         'lng': 28.012091997287314,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.203589637153257,
#           'lng': 28.012091997287314}],
#         'distance': 9821,
#         'postalCode': '2108',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['69 Church Street (Railway Street)',
#          'EGoli',
#          '2108',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57948128'}},
#       'referralId': 'e-0-4d3999306de7721e2527e649-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd37da6d22dc96be807bb0f',
#        'name': 'Alpha Pharm Blairgowrie',
#        'location': {'lat': -26.11583411232001,
#         'lng': 28.01040606611178,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.11583411232001,
#           'lng': 28.01040606611178}],
#         'distance': 9908,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Randburg', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd37da6d22dc96be807bb0f-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5deae8ce6399bf000808da82',
#        'name': 'The Local Choice Pharmacy Blairgowrie',
#        'location': {'address': '70 Conrad Dr',
#         'lat': -26.115577,
#         'lng': 28.0103547,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.115577,
#           'lng': 28.0103547}],
#         'distance': 9918,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['70 Conrad Dr',
#          'Randburg',
#          '2194',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '575238294'}},
#       'referralId': 'e-0-5deae8ce6399bf000808da82-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e52660362840c1260dc28fa',
#        'name': 'Clicks',
#        'location': {'address': 'Brightwater Commons, Republic Rd.',
#         'lat': -26.1016007189932,
#         'lng': 27.990359509973523,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1016007189932,
#           'lng': 27.990359509973523}],
#         'distance': 9323,
#         'postalCode': '2194',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Brightwater Commons, Republic Rd.',
#          'Randburg',
#          '2194',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e52660362840c1260dc28fa-44'}]}]}}

# %% [markdown]
# The next step is to clean the Json file and create a dataframe with columns and rows.

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
Medvenues = BuyMedicine_json['response']['groups'][0]['items']
    
Pharmacy_venues = pd.json_normalize(Medvenues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
Pharmacy_venues =Pharmacy_venues.loc[:, filtered_columns]

# filter the category for each row
Pharmacy_venues['venue.categories'] = Pharmacy_venues.apply(get_category_type, axis=1)

# clean columns
Pharmacy_venues.columns = [col.split(".")[-1] for col in Pharmacy_venues.columns]

Pharmacy_venues
# Out:
#                                                  name      categories  \
# 0                                            Dis-Chem        Pharmacy
# 1                                            Dis-Chem        Pharmacy
# 2                      The Local Choice Pharmacy Park        Pharmacy
# 3                                   Medicare Pharmacy        Pharmacy
# 4                  The Local Choice Pharmacy El Corro        Pharmacy
# 5                                              Clicks  Cosmetics Shop
# 6                        Medicare Pharmacy Palm Court        Pharmacy
# 7                                            Dis-Chem        Pharmacy
# 8                                              Clicks  Cosmetics Shop
# 9                                            Dis-Chem        Pharmacy
# 10                             Clicks Heathway Square        Pharmacy
# 11                      Medicare Pharmacy Weltevreden        Pharmacy
# 12                               Weltevreden Pharmacy        Pharmacy
# 13  Dis-Chem Pharmacy Retail Crossing - Strubensva...        Pharmacy
# 14                            Dis-Chem Pharmacy Verdi        Pharmacy
# 15                           Dis-Chem Pharmacy Cresta        Pharmacy
# 16                                           Dis-Chem        Pharmacy
# 17                         Dis-Chem Pharmacy Westgate        Pharmacy
# 18                        Dis-Chem Pharmacy Randridge        Pharmacy
# 19                                             Clicks  Cosmetics Shop
# 20                                           Dis-chem        Pharmacy
# 21                                           Dis-Chem        Pharmacy
# 22                           Medicare Pharmacy Linden        Pharmacy
# 23                                 Clicks Honey Crest        Pharmacy
# 24                                       Mays Chemist        Pharmacy
# 25                         Dis-Chem Pharmacy Melville        Pharmacy
# 26                                  Guardian Pharmacy        Pharmacy
# 27                                             Clicks        Pharmacy
# 28                    Medicare Pharmacy Fontainebleau        Pharmacy
# 29   Dis-Chem Pharmacy Princess Crossing - Roodepoort        Pharmacy
# 30                                           Dis-chem        Pharmacy
# 31                        Medicare Pharmacy Greenhill        Pharmacy
# 32                     Dis-Chem Pharmacy Victory Park        Pharmacy
# 33                                 Greenside Pharmacy        Pharmacy
# 34                         Medicare Boskruin Pharmacy        Pharmacy
# 35                         Medicare Pharmacy Boskruin        Pharmacy
# 36             Dis-Chem Pharmacy Ferndale On Republic        Pharmacy
# 37                        Medicare Pharmacy Parklands        Pharmacy
# 38                                    Clicks Pharmacy        Pharmacy
# 39                               Witpoortjie Pharmacy        Pharmacy
# 40                      The Local Choice Pharmacy Rox        Pharmacy
# 41                                       Rox Pharmacy        Pharmacy
# 42                            Alpha Pharm Blairgowrie        Pharmacy
# 43              The Local Choice Pharmacy Blairgowrie        Pharmacy
# 44                                             Clicks  Cosmetics Shop
#
#           lat        lng
# 0  -26.126858  27.904855
# 1  -26.115425  27.896948
# 2  -26.159440  27.904598
# 3  -26.150692  27.943865
# 4  -26.144580  27.954464
# 5  -26.136924  27.918601
# 6  -26.125783  27.932122
# 7  -26.137964  28.008667
# 8  -26.127674  27.903798
# 9  -26.139734  27.978989
# 10 -26.127700  27.967629
# 11 -26.134243  27.974180
# 12 -26.134179  27.974216
# 13 -26.116472  27.897125
# 14 -26.139600  27.979028
# 15 -26.131096  27.976512
# 16 -26.101311  27.941109
# 17 -26.140017  27.862155
# 18 -26.101950  27.940000
# 19 -26.130617  27.974158
# 20 -26.135908  27.860187
# 21 -26.130994  27.976093
# 22 -26.135817  27.993101
# 23 -26.093813  27.940458
# 24 -26.176726  28.000973
# 25 -26.182610  28.003010
# 26 -26.104371  27.977083
# 27 -26.181756  28.004671
# 28 -26.104118  27.977190
# 29 -26.130508  27.849577
# 30 -26.125912  27.851562
# 31 -26.161964  28.011873
# 32 -26.138265  28.008561
# 33 -26.147416  28.012358
# 34 -26.086802  27.958977
# 35 -26.086903  27.959582
# 36 -26.099687  27.990144
# 37 -26.138629  28.017531
# 38 -26.094261  27.984941
# 39 -26.133185  27.834544
# 40 -26.203557  28.011976
# 41 -26.203590  28.012092
# 42 -26.115834  28.010406
# 43 -26.115577  28.010355
# 44 -26.101601  27.990360

# %% [markdown]
# ## Map of all the Pharmacies in the area (Red dots)
#
# I use Geocode and Folium to draw up a map and pinpoint locations. All the locations for Pharmacies are pinned in Red

# %%
Pharmacies = folium.Map(location=[-26.1618,27.9255],zoom_start=13)
for lat, lng, name, categories in zip(Pharmacy_venues['lat'], Pharmacy_venues['lng'], Pharmacy_venues['name'], Pharmacy_venues['categories']):
    label = '{}, {}'.format(categories, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#f58e8e',
        fill_opacity=0.7,
        parse_html=False).add_to(Pharmacies) 

Pharmacies
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Hospitals

# %% [markdown]
# For this Foursquare search, I used the Category ID's for Hospitals, Emergency Rooms, Doctors offices and Urgent Care Centers

# %%
urlHOSP = "https://api.foursquare.com/v2/venues/explore?categoryId=4bf58dd8d48988d194941735,4bf58dd8d48988d196941735,4bf58dd8d48988d177941735,56aa371be4b08b9a8d573526&client_id=AKBWLJHMGEQFFNUQ0AZYFLMKNQI0LUL4BWVVX43TMR0MCO5N&client_secret=KZEMDT2LQ3SPMR0H13IUQUDPMMMN24KEVEJMUXT2FM2DKNEB&v=20180605&radius=10000&limit=100&ll=-26.1618,%2027.9255"
Hospitals_json = requests.get(urlHOSP).json()
Hospitals_json
# Out:
# {'meta': {'code': 200, 'requestId': '5e7f48b1df2774001bb8024e'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'query': 'emergency room',
#   'totalResults': 23,
#   'suggestedBounds': {'ne': {'lat': -26.07179990999991,
#     'lng': 28.025585562255472},
#    'sw': {'lat': -26.25180009000009, 'lng': 27.825414437744527}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba209c7f964a520bad737e3',
#        'name': 'Life Flora Clinic',
#        'location': {'address': 'Constantia Blvd',
#         'lat': -26.151518403688453,
#         'lng': 27.92002558708191,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.151518403688453,
#           'lng': 27.92002558708191}],
#         'distance': 1268,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Constantia Blvd',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba209c7f964a520bad737e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb81a3a035d236a414fca4e',
#        'name': 'Mayo Clinic',
#        'location': {'lat': -26.15065491854721,
#         'lng': 27.9205721754636,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.15065491854721,
#           'lng': 27.9205721754636}],
#         'distance': 1334,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb81a3a035d236a414fca4e-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dac57684b22f071eae0795b',
#        'name': 'Medicross Randburg',
#        'location': {'address': 'Rabie St',
#         'crossStreet': 'Malibongwe Dr',
#         'lat': -26.110719515030052,
#         'lng': 27.989679257839235,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.110719515030052,
#           'lng': 27.989679257839235}],
#         'distance': 8571,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Rabie St (Malibongwe Dr)',
#          'Randburg',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d104941735',
#          'name': 'Medical Center',
#          'pluralName': 'Medical Centers',
#          'shortName': 'Medical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dac57684b22f071eae0795b-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bed68089868a593e34e5d46',
#        'name': 'Strubensvalley Medical Centre',
#        'location': {'address': 'Hendrick Potgieter',
#         'lat': -26.120884,
#         'lng': 27.901995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.120884,
#           'lng': 27.901995}],
#         'distance': 5124,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Hendrick Potgieter',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bed68089868a593e34e5d46-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee1dd44e5fa204a5475ef22',
#        'name': 'Dr Chane Magnus',
#        'location': {'address': 'Block 4 Suite 1 Ruimsig Office Estate, Cnr Peter Road & Hole-In-One Avenue',
#         'crossStreet': 'Hole-In-One Avenue',
#         'lat': -26.135487,
#         'lng': 27.969423,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.135487,
#           'lng': 27.969423}],
#         'distance': 5276,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Block 4 Suite 1 Ruimsig Office Estate, Cnr Peter Road & Hole-In-One Avenue (Hole-In-One Avenue)',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '219204907'}},
#       'referralId': 'e-0-4ee1dd44e5fa204a5475ef22-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c60fba090b2c9b69d2a3e22',
#        'name': 'Rahima Moosa Mother and Child Hospital',
#        'location': {'lat': -26.18914500168089,
#         'lng': 27.971888147745602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.18914500168089,
#           'lng': 27.971888147745602}],
#         'distance': 5544,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Randburg', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c60fba090b2c9b69d2a3e22-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8a7a2cdab4414a6b11f516',
#        'name': 'Triomf Medicross',
#        'location': {'lat': -26.17492715343303,
#         'lng': 27.979232998003834,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.17492715343303,
#           'lng': 27.979232998003834}],
#         'distance': 5563,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8a7a2cdab4414a6b11f516-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d399c006de7721e8745e649',
#        'name': 'Northcliff Health Centre',
#        'location': {'address': 'Beyers Naude Drive',
#         'crossStreet': 'Waugh Ave',
#         'lat': -26.137717582141068,
#         'lng': 27.97724839686346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.137717582141068,
#           'lng': 27.97724839686346}],
#         'distance': 5824,
#         'cc': 'ZA',
#         'city': 'Northcliff',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Beyers Naude Drive (Waugh Ave)',
#          'Northcliff',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d399c006de7721e8745e649-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d062e76347da1cd75ab348f',
#        'name': 'Dr. Dorianne Green',
#        'location': {'address': '151 Beyers Naudé Drive, Roosevelt Park',
#         'lat': -26.145999999999997,
#         'lng': 27.984500000000025,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.145999999999997,
#           'lng': 27.984500000000025}],
#         'distance': 6152,
#         'postalCode': '2195',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['151 Beyers Naudé Drive, Roosevelt Park',
#          'EGoli',
#          '2195',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d062e76347da1cd75ab348f-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5deae01f25d4310008caca18',
#        'name': 'Intercare Wilgeheuwel',
#        'location': {'address': 'Hendrik Potgieter Road',
#         'lat': -26.11340176,
#         'lng': 27.89361528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.11340176,
#           'lng': 27.89361528}],
#         'distance': 6259,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Hendrik Potgieter Road',
#          'Roodepoort',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '579932508'}},
#       'referralId': 'e-0-5deae01f25d4310008caca18-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b558afaf964a520f9e627e3',
#        'name': 'Helen Joseph Hospital',
#        'location': {'address': 'Perth Rd. Westdene',
#         'lat': -26.18465324928566,
#         'lng': 27.990053547357448,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.18465324928566,
#           'lng': 27.990053547357448}],
#         'distance': 6932,
#         'postalCode': '2092',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Perth Rd. Westdene',
#          'EGoli',
#          '2092',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b558afaf964a520f9e627e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bee97cb3686c9b695a8246e',
#        'name': 'Life Wilgeheuwel Hospital',
#        'location': {'address': 'Amplifier St',
#         'crossStreet': 'Cnr Christiaan De Wet',
#         'lat': -26.099023930433518,
#         'lng': 27.92528062113792,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.099023930433518,
#           'lng': 27.92528062113792}],
#         'distance': 6988,
#         'postalCode': '1724',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Amplifier St (Cnr Christiaan De Wet)',
#          'EGoli',
#          '1724',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bee97cb3686c9b695a8246e-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9f02d08afca093529b0616',
#        'name': 'Johannesburg Specialist Vet',
#        'location': {'address': '51 Kayburne Ave',
#         'crossStreet': 'John Voster',
#         'lat': -26.099694,
#         'lng': 27.941429615020752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.099694,
#           'lng': 27.941429615020752}],
#         'distance': 7094,
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['51 Kayburne Ave (John Voster)',
#          'Randburg',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9f02d08afca093529b0616-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ddfb4f318388714bb6e60d2',
#        'name': 'Tshepo-Themba Private Hospital',
#        'location': {'address': 'Johannesburg',
#         'lat': -26.205921276391464,
#         'lng': 27.87362403082895,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.205921276391464,
#           'lng': 27.87362403082895}],
#         'distance': 7139,
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Johannesburg', 'EGoli', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ddfb4f318388714bb6e60d2-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58b59b8c5cab2f599583783c',
#        'name': 'Alex Reid Physiotherapy',
#        'location': {'address': 'Ysterhout drive and Beyers Naude avenue',
#         'lat': -26.0963697,
#         'lng': 27.943685200000004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.0963697,
#           'lng': 27.943685200000004}],
#         'distance': 7506,
#         'postalCode': '2169',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Ysterhout drive and Beyers Naude avenue',
#          'Randburg',
#          '2169',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '403112307'}},
#       'referralId': 'e-0-58b59b8c5cab2f599583783c-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4beba57761aca5931c518500',
#        'name': 'Medicross Meldene',
#        'location': {'address': '3rd Ave',
#         'crossStreet': 'Main St',
#         'lat': -26.17695361456294,
#         'lng': 28.001049240046335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.17695361456294,
#           'lng': 28.001049240046335}],
#         'distance': 7734,
#         'postalCode': '2109',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['3rd Ave (Main St)',
#          'EGoli',
#          '2109',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4beba57761aca5931c518500-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bee5e6bd355a593ebd30a60',
#        'name': 'NHC Health Centre',
#        'location': {'address': 'Christiaan de Wet',
#         'crossStreet': 'Dolfyn',
#         'lat': -26.089119276652777,
#         'lng': 27.928769126777546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.089119276652777,
#           'lng': 27.928769126777546}],
#         'distance': 8097,
#         'cc': 'ZA',
#         'city': 'Randparkridge',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Christiaan de Wet (Dolfyn)',
#          'Randparkridge',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bee5e6bd355a593ebd30a60-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbf55a7b083a5933938a3e9',
#        'name': 'Medicross Princess Crossing',
#        'location': {'address': 'Ontdekkers Road',
#         'lat': -26.130712491153037,
#         'lng': 27.852020271062013,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.130712491153037,
#           'lng': 27.852020271062013}],
#         'distance': 8117,
#         'cc': 'ZA',
#         'city': 'Roodepoort',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Ontdekkers Road',
#          'Roodepoort',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbf55a7b083a5933938a3e9-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfb84eed0382d7fa1c5c90a',
#        'name': 'Garden City Clinic',
#        'location': {'address': '35 Bartlett Rd. Mayfair',
#         'lat': -26.19723311457942,
#         'lng': 28.00475986922529,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.19723311457942,
#           'lng': 28.00475986922529}],
#         'distance': 8846,
#         'postalCode': '2108',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['35 Bartlett Rd. Mayfair',
#          'EGoli',
#          '2108',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfb84eed0382d7fa1c5c90a-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8acbd72c5bb8eed7cee97a',
#        'name': '@ Garden City Clinic Pharmacy',
#        'location': {'address': '35 Bartlett Road, Mayfair West',
#         'lat': -26.197477946641072,
#         'lng': 28.007363915758347,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.197477946641072,
#           'lng': 28.007363915758347}],
#         'distance': 9091,
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['35 Bartlett Road, Mayfair West',
#          'EGoli',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8acbd72c5bb8eed7cee97a-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd8e88d1838b8561d0c0465',
#        'name': 'Netcare Rehabilitation Hospital',
#        'location': {'lat': -26.18799318004126,
#         'lng': 28.012081513892213,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.18799318004126,
#           'lng': 28.012081513892213}],
#         'distance': 9128,
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd8e88d1838b8561d0c0465-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb48897f187a593f33314f8',
#        'name': 'Milpark hospital',
#        'location': {'address': '9 Guild road Parktown West',
#         'crossStreet': 'Barry Hertzog',
#         'lat': -26.179927,
#         'lng': 28.017588,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.179927,
#           'lng': 28.017588}],
#         'distance': 9418,
#         'postalCode': '2006',
#         'cc': 'ZA',
#         'neighborhood': 'Milpark',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['9 Guild road Parktown West (Barry Hertzog)',
#          'EGoli',
#          '2006',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d196941735',
#          'name': 'Hospital',
#          'pluralName': 'Hospitals',
#          'shortName': 'Hospital',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb48897f187a593f33314f8-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf798d39d11b1f77eb2c6ed',
#        'name': 'Crescent Clinic',
#        'location': {'address': 'President Fouche Dr',
#         'crossStreet': 'Hawken Ave',
#         'lat': -26.08829826109324,
#         'lng': 27.958611540478984,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.08829826109324,
#           'lng': 27.958611540478984}],
#         'distance': 8826,
#         'postalCode': '2154',
#         'cc': 'ZA',
#         'city': 'Randburg',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['President Fouche Dr (Hawken Ave)',
#          'Randburg',
#          '2154',
#          'iNingizimu Afrika']},
#        'categories': [{'id': '4bf58dd8d48988d104941735',
#          'name': 'Medical Center',
#          'pluralName': 'Medical Centers',
#          'shortName': 'Medical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf798d39d11b1f77eb2c6ed-22'}]}]}}

# %% [markdown]
# The next step is to clean the Json file and create a dataframe with columns and rows.

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
Hospvenues = Hospitals_json['response']['groups'][0]['items']
    
Hospital_venues = pd.json_normalize(Hospvenues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
Hospital_venues =Hospital_venues.loc[:, filtered_columns]

# filter the category for each row
Hospital_venues['venue.categories'] = Hospital_venues.apply(get_category_type, axis=1)

# clean columns
Hospital_venues.columns = [col.split(".")[-1] for col in Hospital_venues.columns]

Hospital_venues
# Out:
#                                       name       categories        lat  \
# 0                        Life Flora Clinic         Hospital -26.151518
# 1                              Mayo Clinic  Doctor's Office -26.150655
# 2                       Medicross Randburg   Medical Center -26.110720
# 3            Strubensvalley Medical Centre  Doctor's Office -26.120884
# 4                          Dr Chane Magnus  Doctor's Office -26.135487
# 5   Rahima Moosa Mother and Child Hospital         Hospital -26.189145
# 6                         Triomf Medicross  Doctor's Office -26.174927
# 7                 Northcliff Health Centre  Doctor's Office -26.137718
# 8                       Dr. Dorianne Green  Doctor's Office -26.146000
# 9                    Intercare Wilgeheuwel  Doctor's Office -26.113402
# 10                   Helen Joseph Hospital         Hospital -26.184653
# 11               Life Wilgeheuwel Hospital         Hospital -26.099024
# 12             Johannesburg Specialist Vet  Doctor's Office -26.099694
# 13          Tshepo-Themba Private Hospital         Hospital -26.205921
# 14                 Alex Reid Physiotherapy  Doctor's Office -26.096370
# 15                       Medicross Meldene  Doctor's Office -26.176954
# 16                       NHC Health Centre  Doctor's Office -26.089119
# 17             Medicross Princess Crossing  Doctor's Office -26.130712
# 18                      Garden City Clinic         Hospital -26.197233
# 19           @ Garden City Clinic Pharmacy         Hospital -26.197478
# 20         Netcare Rehabilitation Hospital         Hospital -26.187993
# 21                        Milpark hospital         Hospital -26.179927
# 22                         Crescent Clinic   Medical Center -26.088298
#
#           lng
# 0   27.920026
# 1   27.920572
# 2   27.989679
# 3   27.901995
# 4   27.969423
# 5   27.971888
# 6   27.979233
# 7   27.977248
# 8   27.984500
# 9   27.893615
# 10  27.990054
# 11  27.925281
# 12  27.941430
# 13  27.873624
# 14  27.943685
# 15  28.001049
# 16  27.928769
# 17  27.852020
# 18  28.004760
# 19  28.007364
# 20  28.012082
# 21  28.017588
# 22  27.958612

# %% [markdown]
# ## Map of all the Medical centers in the area (Yellow dots)
#
# I use Geocode and Folium to draw up a map and pinpoint locations. All the locations for Hospitals are pinned in Yellow

# %%
Medical = folium.Map(location=[-26.1618,27.9255],zoom_start=13)

for lat, lng, name, categories in zip(Hospital_venues['lat'], Hospital_venues['lng'], Hospital_venues['name'], Hospital_venues['categories']):
    label = '{}, {}'.format(categories, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='#fed37e',
        fill_opacity=0.7,
        parse_html=False).add_to(Medical) 
    
Medical
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Location Map

# %% [markdown]
# I use Geocode and Folium to draw up a map and pinpoint locations.  All the locations for Grocery stores are pinned in Blue.  Locations for Pharmacies are pinned in Red. And Locations for Hospitals are pinned in Yellow

# %%
EssentialShop = folium.Map(location=[-26.1618,27.9255],zoom_start=13)
for lat, lng, name, categories in zip(Grocery_venues['lat'], Grocery_venues['lng'], Grocery_venues['name'], Grocery_venues['categories']):
    label = '{}, {}'.format(categories, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(EssentialShop) 
for lat, lng, name, categories in zip(Pharmacy_venues['lat'], Pharmacy_venues['lng'], Pharmacy_venues['name'], Pharmacy_venues['categories']):
    label = '{}, {}'.format(categories, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#f58e8e',
        fill_opacity=0.7,
        parse_html=False).add_to(EssentialShop) 
for lat, lng, name, categories in zip(Hospital_venues['lat'], Hospital_venues['lng'], Hospital_venues['name'], Hospital_venues['categories']):
    label = '{}, {}'.format(categories, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='#fed37e',
        fill_opacity=0.7,
        parse_html=False).add_to(EssentialShop) 
    
EssentialShop
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
